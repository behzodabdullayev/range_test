# %%
print('--6 karra jadvali--')
son = 6
for a in range(1, 10):
    natija = son * a
    print(f'{son} x {a} = {natija}')
# Out:
# --6 karra jadvali--
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
